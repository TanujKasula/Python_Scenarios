# %% [markdown]
# **3. Filtering high-value transactions from a CSV file for targeted promotions.**

# %%
import pandas as pd

df1=pd.read_csv('../Results/Result_02.csv')
df1
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#                phone                                            address  \
# 0    +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
df2=pd.read_csv('../Datasets/transaction_data.csv')
df2
# Out:
#      transaction_id  customer_id   amount     transaction_date  \
# 0                 1          565  2992.47  2025-03-10 01:20:54
# 1                 2          323  2041.87  2025-01-02 15:24:19
# 2                 3          398   107.35  2025-02-16 03:49:01
# 3                 4           19      NaN  2025-04-30 15:26:23
# 4                 5          547  3063.28  2025-06-14 04:28:53
# ..              ...          ...      ...                  ...
# 995             996           60   712.47  2025-01-13 14:16:32
# 996             997          235  2125.18  2025-06-09 12:37:36
# 997             998          669  3069.08  2025-04-01 19:59:01
# 998             999          931  2262.75  2025-06-08 01:36:01
# 999            1000          925  4141.44  2025-05-24 13:39:19
#
#     product_category payment_method store_location
# 0             Sports     Debit Card       New York
# 1           Clothing           Cash       New York
# 2             Beauty     Debit Card         Online
# ...

# %%
df2.isna().sum()
# Out:
# transaction_id       0
# customer_id          0
# amount              50
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
mean=df2['amount'].mean()
df2['amount'].fillna(mean,inplace=True)
# Out:
# C:\Users\Tanuj\AppData\Local\Temp\ipykernel_12436\3062361381.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['amount'].fillna(mean,inplace=True)

# %%
df2.isna().sum()
# Out:
# transaction_id      0
# customer_id         0
# amount              0
# transaction_date    0
# product_category    0
# payment_method      0
# store_location      0
# dtype: int64

# %%
df3=pd.merge(df1,df2,on='customer_id',how='inner')
df3
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 4              7      Louis Miller  patriciaelliott@example.org
# ..           ...               ...                          ...
# 995          995    Deanna Johnson            ycook@example.org
# 996          995    Deanna Johnson            ycook@example.org
# 997          997      Jodi Simpson           eric24@example.org
# 998          998     Crystal Brown         pshaffer@example.net
# 999          998     Crystal Brown         pshaffer@example.net
#
#                phone                                            address  \
# 0    +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
df3.isna().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# Country_Code_Name    0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
# df3.to_csv('..\Results\Cleaned_Transaction.csv')

# %%
df4=df3[df3['amount']>1000]
df4
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 6             10      Rachel White     whitemichael@example.org
# ..           ...               ...                          ...
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org
# 993          995    Deanna Johnson            ycook@example.org
# 994          995    Deanna Johnson            ycook@example.org
# 999          998     Crystal Brown         pshaffer@example.net
#
#                phone                                            address  \
# 0    +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
df4.to_csv('..\Results\Result_03.csv')
