# %%
# %pip install pyodbc

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# colorama                0.4.6
# comm                    0.2.2
# debugpy                 1.8.14
# decorator               5.2.1
# executing               2.2.0
# ipykernel               6.29.5
# ipython                 9.3.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# matplotlib-inline       0.1.7
# nest-asyncio            1.6.0
# numpy                   2.3.0
# packaging               25.0
# pandas                  2.3.0
# parso                   0.8.4
# pip                     24.0
# platformdirs            4.3.8
# prompt_toolkit          3.0.51
# psutil                  7.0.0
# pure_eval               0.2.3
# Pygments                2.19.1
# pyodbc                  5.2.0
# python-dateutil         2.9.0.post0
# pytz                    2025.2
# pywin32                 310
# ...

# %%
# %pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyodbc
import pandas as pd

# %%
SERVER = 'DESKTOP-HJVSCEN\MSSQLSERVER1'
DATABASE = 'Python ETL'
USERNAME = 'sa'
PASSWORD = 'Ka@12345678'

# %%
connectionString = f'DRIVER={{SQL Server}};SERVER={SERVER};DATABASE={DATABASE};UID={USERNAME};PWD={PASSWORD}'

# %%
df1=pd.read_csv('..\Results\Result_02.csv')
df1.isna().sum()
df1
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#                phone                                            address  \
# 0    +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
df1['registration_date']=pd.to_datetime(df1['registration_date'],dayfirst=True)

# %%
df1.drop(columns=['Country_Code_Name'])
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#                phone                                            address  \
# 0    +971 6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
df1['phone'] = df1['phone'].str[-10:]
print(df1.dtypes)
# Out:
# customer_id                   int64
# name                         object
# email                        object
# phone                        object
# address                      object
# registration_date    datetime64[ns]
# loyalty_status               object
# Country_Code_Name            object
# dtype: object

# %%
df1.to_csv('../Datasets/Cleaned_customer.csv',index=False)

# %%
df=pd.read_csv('../Datasets/Cleaned_customer.csv')
df

# %%
print(df.dtypes)
# Out:
# Unnamed: 0            int64
# customer_id           int64
# name                 object
# email                object
# phone                object
# address              object
# registration_date    object
# loyalty_status       object
# Country_Code_Name    object
# dtype: object

# %% [markdown]
# **STEP 1: CREATE  a table**

# %%
with pyodbc.connect(connectionString) as conn:
    cursor=conn.cursor()
    create_table_query='''
                        create table customers(
                        customer_id int primary key,
                    	customer_name varchar(max),
                        email varchar(50),
                        phone varchar(20),
                        address varchar(max),
                        registration_date date,
                        loyalty_status varchar(10)
                        )
                    '''
    cursor.execute(create_table_query)

# %% [markdown]
# Convert the registration date type from object data type(in pandas is equal to string data type) to a date type to insert into the table column

# %%
with pyodbc.connect(connectionString) as con:
    cursor=con.cursor()
    insert_values='''
                    insert into customers(customer_id,customer_name,email,phone,address,registration_date,loyalty_status)
                    values(?,?,?,?,?,?,?)
                    '''
    for index,row in df.iterrows():
        cursor.execute(insert_values,
                                    row['customer_id'],
                                    row['name'],
                                    row['email'],
                                    row['phone'],
                                    row['address'],
                                    row['registration_date'],
                                    row['loyalty_status']
                        )
#when running second time insertion you will get the error due to primary key constraint
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[120], line 8
#       3 insert_values='''
#       4                 insert into customers(customer_id,customer_name,email,phone,address,registration_date,loyalty_status)
#       5                 values(?,?,?,?,?,?,?)
#       6                 '''
#       7 for index,row in df.iterrows():
# ----> 8     cursor.execute(insert_values,
#       9                                 row['customer_id'],
#      10                                 row['name'],
#      11                                 row['email'],
#      12                                 row['phone'],
#      13                                 row['address'],
#      14                                 row['registration_date'],
#      15                                 row['loyalty_status']
#      16                     )
#
# ...
